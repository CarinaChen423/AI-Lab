# %%
# AI LAB 1a TASK 1_1
# a. If activation function is linear(identity),
# b. If activation function is sigmoid,compute the activated outputs of the artificial neuron given above, using the following dataset. (Select 
# your own random values for the weights and bias)

# a.
import numpy as np
import matplotlib.pyplot as plt
def sigmoid(z):
    return 1 / (1 + np.exp(-x))

# Dataset
x1 = np.array([1, 0.5, 3, 2.5])
x2 = np.array([2, 2.5, 0.5, 0.4])
Class = np.array(['A', 'A', 'B', 'B'])

# Random values for the weights and bias

w1 = np.random.randn()
w2 = np.random.randn()
b = np.random.randn()

# Computed weighted sum of inputs plus bias
x = w1*x1 + w2*x2 + b

output = sigmoid(x)

# RESULT
print(output)
# Out:
# [0.13854785 0.11288753 0.27268456 0.24846662]

# %% [markdown]
# ![image.png](attachment:b2637f2c-129c-4c4f-a321-51387da8c68f.png)

# %%
# b.
import numpy as np

def linear(x):
    return x
p = np.array([[1,2],[0.5,2.5],[3,0.5],[2.5,0.4]])
Class = np.array(['A', 'A', 'B', 'B'])

w1 = np.random.randn()
w2 = np.random.randn()
bias = np.random.randn()

x = w1*x1 + w2*x2 + bias

res = linear(x)

print(res)
# Out:
# [-0.69662282 -0.84500709 -0.21298752 -0.22948962]

# %%
# 2. a) 
# Set the weights and bias values as 𝑊 = [1.6 1.2] b = - 3.9 and activation function as 
# hardlim for the artificial neuron given below. Verify that if the artificial neuron can correctly 
# classify the data given below.

import numpy as np

# Define the activation function
def hardlim(x):
    if x >= 0:
        return 1
    else:
        return 0

# Define the inputs and weights
X = np.array([[-1, 0], [0, 3], [2, 0], [3, 3]])
W = np.array([1.6, 1.2])
b = -3.9

# Calculate the activations
y = np.zeros(4)
for i in range(4):
    a = np.dot(X[i], W) + b
    y[i] = hardlim(a)

# Compare the activations to the target class
target = np.array([0, 0, 0, 1])
if np.array_equal(y, target):
    print("The artificial neuron correctly classified the data.")
else:
    print("The artificial neuron did not correctly classify the data.")

# %% [markdown]
# ![image.png](attachment:62360916-390d-4c76-b707-d71d378c41ae.png)

# %%
# b) Set the weights and bias values as 𝑊 = [1.41 1.41] b = - 0.7 and activation function as 
# hardlim for the artificial neuron given below. Verify that if the artificial neuron can correctly 
# classify the data given below.

import numpy as np

# Define the activation function
def hardlim(x):
    if x >= 0:
        return 1
    else:
        return 0

# Define the inputs and weights
X = np.array([[-1, 0], [0, 3], [2, 0], [3, 3]])
W = np.array([1.41, 1.41])
b = -0.7

# Calculate the activations
y = np.zeros(4)
for i in range(4):
    a = np.dot(X[i], W) + b
    y[i] = hardlim(a)

# Compare the activations to the target class
target = np.array([0, 0, 0, 1])
if np.array_equal(y, target):
    print("The artificial neuron correctly classified the data.")
else:
    print("The artificial neuron did not correctly classify the data.")

# %%
# AI LAB 1b
# Task 1 Solve the logic AND problem using Perceptron neuron model

import numpy as np 
  
# define Unit Step Function 
def unitStep(v): 
    if v >= 0: 
        return 1
    else: 
        return 0
# define Perceptron Model
def perceptronModel(x, w, b): 
    v = np.dot(w, x) + b 
    y = unitStep(v) 
    return y 
  
# AND Logic Function; w1 = 1, w2 = 1, b = -1.5 
def AND_logicFunction(x): 
    w = np.array([1, 1]) 
    b = -1.5
    return perceptronModel(x, w, b) 
  
# testing the Perceptron Model 
test1 = np.array([0, 0]) 
test2 = np.array([0, 1]) 
test3 = np.array([1, 0]) 
test4 = np.array([1, 1]) 
  
print("AND({}, {}) = {}".format(0, 0, AND_logicFunction(test1))) 
print("AND({}, {}) = {}".format(0, 1, AND_logicFunction(test2))) 
print("AND({}, {}) = {}".format(1, 0, AND_logicFunction(test3))) 
print("AND({}, {}) = {}".format(1, 1, AND_logicFunction(test4)))
# Out:
# AND(0, 0) = 0
# AND(0, 1) = 0
# AND(1, 0) = 0
# AND(1, 1) = 1

# %% [markdown]
# ![image.png](attachment:addd830e-5a04-443d-a6a9-8b5e843dbe42.png)
# ![image.png](attachment:d422d97d-6ee7-4f89-8246-399fed1b1aaa.png)

# %%
# TASK 2: Solve the logic OR problem using Perceptron neuron model

import numpy as np 
  
# define Unit Step Function 
def unitStep(v): 
    if v >= 0: 
        return 1
    else: 
        return 0
# define Perceptron Model
def perceptronModel(x, w, b): 
    v = np.dot(w, x) + b 
    y = unitStep(v) 
    return y 
  
# OR Logic Function 
# w1 = 1, w2 = 1, b = -0.5 
def OR_logicFunction(x): 
    w = np.array([1, 1]) 
    b = -0.5
    return perceptronModel(x, w, b) 
  
# testing the Perceptron Model 
test1 = np.array([0, 0]) 
test2 = np.array([0, 1]) 
test3 = np.array([1, 0]) 
test4 = np.array([1, 1]) 
  
print("OR({}, {}) = {}".format(0, 0, OR_logicFunction(test1))) 
print("OR({}, {}) = {}".format(0, 1, OR_logicFunction(test2))) 
print("OR({}, {}) = {}".format(1, 0, OR_logicFunction(test3))) 
print("OR({}, {}) = {}".format(1, 1, OR_logicFunction(test4)))
# Out:
# OR(0, 0) = 0
# OR(0, 1) = 1
# OR(1, 0) = 1
# OR(1, 1) = 1

# %% [markdown]
# ![image.png](attachment:8d22f3b1-b3da-4a3f-a3c5-be9e11f99e30.png)
